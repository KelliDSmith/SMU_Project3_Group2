# %%
import pandas as pd

# %%
df = pd.read_json("../data/dog_clean_time.json")
df.head()
# Out:
#    intake_year  intake_month  count
# 0         2013            10    963
# 1         2013            11    816
# 2         2013            12    852
# 3         2014             1    876
# 4         2014             2    818

# %%
print(df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>intake_year</th>
#       <th>intake_month</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2013</td>
#       <td>10</td>
#       <td>963</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2013</td>
#       <td>11</td>
#       <td>816</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2013</td>
#       <td>12</td>
#       <td>852</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2014</td>
#       <td>1</td>
#       <td>876</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2014</td>
#       <td>2</td>
#       <td>818</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2014</td>
#       <td>3</td>
#       <td>894</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2014</td>
#       <td>4</td>
#       <td>857</td>
#     </tr>
#     <tr>
#       <th>7</th>
# ...
