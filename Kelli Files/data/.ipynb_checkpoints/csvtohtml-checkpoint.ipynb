# %%
import pandas as pd

# %%
df = pd.read_csv("../data/time_series_table.csv")
df.head()
# Out:
#   animal_type  intake_year  intake_month  count
# 0         Cat         2014             1    335
# 1         Cat         2014             2    268
# 2         Cat         2014             3    353
# 3         Cat         2014             4    566
# 4         Cat         2014             5    901

# %%
result = df.to_html()
print(result)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>animal_type</th>
#       <th>intake_year</th>
#       <th>intake_month</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Cat</td>
#       <td>2014</td>
#       <td>1</td>
#       <td>335</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Cat</td>
#       <td>2014</td>
#       <td>2</td>
#       <td>268</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Cat</td>
#       <td>2014</td>
#       <td>3</td>
#       <td>353</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Cat</td>
#       <td>2014</td>
#       <td>4</td>
#       <td>566</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Cat</td>
#       <td>2014</td>
#       <td>5</td>
#       <td>901</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Cat</td>
#       <td>2014</td>
#       <td>6</td>
#       <td>821</td>
# ...
