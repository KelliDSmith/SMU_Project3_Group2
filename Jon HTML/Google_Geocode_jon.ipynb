# %%
# Dependencies
import requests
import json

# Google developer API key
from config import gkey
import pandas as pd 
import numpy as np

# Target city
target_city = "9409 Bluegrass Dr in Austin (TX)"

# Build the endpoint URL
target_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={target_city}&key={gkey}"

target_url
# Out:
# 'https://maps.googleapis.com/maps/api/geocode/json?address=9409 Bluegrass Dr in Austin (TX)&key=AIzaSyAC9pOcEwqn4hfurVjPS0KV-oosjf9-V48'

# %%
df = pd.read_csv("austin_animal_address_v2.csv")
# df.head
address_df = pd.DataFrame(df)

address_df
# Out:
#    animal_id                              found_location
# 0    A668614    0 E Martin Luther King Jr in Austin (TX)
# 1    A717686                            0 in Austin (TX)
# 2    A730114             0 W Cesar Chavez in Austin (TX)
# 3    A752999             0000 Bittercreek in Austin (TX)
# 4    A715887                 0000 Bolm Rd in Austin (TX)
# 5    A715886                 0000 Bolm Rd in Austin (TX)
# 6    A508027           0000 E 14Th 1/2 St in Austin (TX)
# 7    A349733             0000 Landsman Dr in Austin (TX)
# 8    A682366          0000 Onion Creek Rd in Austin (TX)
# 9    A712141             0000 South First in Austin (TX)
# 10   A711165           0000 Springdale Rd in Austin (TX)
# 11   A717817              0000 Wickersham in Austin (TX)
# 12   A709013             00000 Briarcliff in Travis (TX)
# 13   A709011             00000 Briarcliff in Travis (TX)
# 14   A709014             00000 Briarcliff in Travis (TX)
# 15   A724845                  1 Radnor Dr in Travis (TX)
# 16   A739815                 1 Swiftwater in Travis (TX)
# 17   A707217               10 Casa Verde in Lakeway (TX)
# 18   A707218               10 Casa Verde in Lakeway (TX)
# 19   A758273         10 Love Grass in Sunset Valley (TX)
# 20   A758272         10 Love Grass in Sunset Valley (TX)
# 21   A766665                100 Beaver St in Austin (TX)
# 22   A725713      100 Block Of East Murray in Manor (TX)
# 23   A746917  100 Block Ralph Ablanedo Dr in Austin (TX)
# 24   A746677                100 Chicon St in Austin (TX)
# 25   A710829                 100 Congress in Austin (TX)
# 26   A575920            100 E Anderson Ln in Austin (TX)
# 27   A742353            100 E Eggleston St in Manor (TX)
# 28   A701465             100 E Hoopes Ave in Travis (TX)

# %%
# Run a request to endpoint and convert result to json
response = requests.get(target_url)

geo_data = response.json()

# Print the json
print(geo_data)
# Out:
# {'results': [{'address_components': [{'long_name': '9409', 'short_name': '9409', 'types': ['street_number']}, {'long_name': 'Bluegrass Drive', 'short_name': 'Bluegrass Dr', 'types': ['route']}, {'long_name': 'Great Hills', 'short_name': 'Great Hills', 'types': ['neighborhood', 'political']}, {'long_name': 'Austin', 'short_name': 'Austin', 'types': ['locality', 'political']}, {'long_name': 'Travis County', 'short_name': 'Travis County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '78759', 'short_name': '78759', 'types': ['postal_code']}, {'long_name': '6230', 'short_name': '6230', 'types': ['postal_code_suffix']}], 'formatted_address': '9409 Bluegrass Dr, Austin, TX 78759, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.3993959, 'lng': -97.7669847}, 'southwest': {'lat': 30.3990216, 'lng': -97.7673361}}, 'location': {'lat': 30.3991926, 'lng': -97.7670952}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 30.4005577302915, 'lng': -97.76581141970848}, 'southwest': {'lat': 30.3978597697085, 'lng': -97.7685093802915}}}, 'place_id': 'ChIJvyZwPqPMRIYRjQytEkoy8Tw', 'types': ['premise']}], 'status': 'OK'}

# %%
# Extract latitude and longitude
lat = geo_data["results"][0]["geometry"]["location"]["lat"]
lng = geo_data["results"][0]["geometry"]["location"]["lng"]

lats= []
lngs = []

addresses = address_df.found_location

for address in addresses:
    target_url= f"https://maps.googleapis.com/maps/api/geocode/json?address={address}&key={gkey}"
    response = requests.get(target_url)
    
    if response.status_code == 200:
        data = response.json()
        
        try:
            lat = data["results"][0]["geometry"]["location"]["lat"]
            lng = data["results"][0]["geometry"]["location"]["lng"]
            lats.append(lat)
            lngs.append(lng)
        
        except:
            lats.append(np.nan)
            lngs.append(np.nan)
            



# # Print the latitude and longitude
# print('''
#     City: {0}
#     Latitude: {1}
#     Longitude: {2}
#     '''.format(target_city, lat, lng))

location_df = pd.DataFrame()
location_df["address"] = addresses
location_df["latitude"] = lats
location_df["longitude"] = lngs
location_df.head()


##wrap in try catch just like in week 6 API homework
# Out:
#                                     address   latitude  longitude
# 0  0 E Martin Luther King Jr in Austin (TX)  30.281564 -97.714005
# 1                          0 in Austin (TX)  30.233702 -97.792277
# 2           0 W Cesar Chavez in Austin (TX)  30.258519 -97.728660
# 3           0000 Bittercreek in Austin (TX)  30.183953 -97.761123
# 4               0000 Bolm Rd in Austin (TX)  30.254570 -97.680332

# %%
len(lats)
# Out:
# 29

# %%
len(lngs)
# Out:
# 29

# %%
location_df.to_csv('animal_location.csv', index=False)
